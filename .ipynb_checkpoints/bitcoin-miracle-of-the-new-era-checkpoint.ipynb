# %% [markdown]
# ## Importing Libraries

# %%
# %matplotlib inline 

import os
import numpy as np
import pandas as pd
import quandl
import glob

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

plt.style.use('fivethirtyeight')
pd.set_option('display.max_columns', None)

# %%
#API configuration

API_KEY = 'VsPJfDEFmdcJCX--41xq'
quandl.ApiConfig.api_key = API_KEY

# %%
#pulling data from quandl

'''
df_mywallet_users = quandl.get("BCHAIN/MWNUS", start_date="2011-09-13", end_date="2020-07-10") 
df_bitcoin_price = quandl.get("BCHAIN/MKPRU", start_date="2011-09-13", end_date="2020-07-10")
df_trade_volume = quandl.get("BCHAIN/MKPRU", start_date="2011-09-13", end_date="2020-07-10")
df_diffculty = quandl.get("BCHAIN/DIFF", start_date="2011-09-13", end_date="2020-07-10")
df_wallet_trans = quandl.get("BCHAIN/MWNTD", start_date="2011-09-13", end_date="2020-07-10")
df_trans_volume = quandl.get("BCHAIN/MWTRV", start_date="2011-09-13", end_date="2020-07-10")
df_block_size = quandl.get("BCHAIN/AVBLS", start_date="2011-09-13", end_date="2020-07-10")
df_api_size = quandl.get("BCHAIN/BLCHS", start_date="2011-09-13", end_date="2020-07-10")
df_miners_rev = quandl.get("BCHAIN/MIREV", start_date="2011-09-13", end_date="2020-07-10")
df_hash_rate = quandl.get("BCHAIN/HRATE", start_date="2011-09-13", end_date="2020-07-10")

'''
# Out:
# '\ndf_mywallet_users = quandl.get("BCHAIN/MWNUS", start_date="2011-09-13", end_date="2020-07-10") \ndf_bitcoin_price = quandl.get("BCHAIN/MKPRU", start_date="2011-09-13", end_date="2020-07-10")\ndf_trade_volume = quandl.get("BCHAIN/MKPRU", start_date="2011-09-13", end_date="2020-07-10")\ndf_diffculty = quandl.get("BCHAIN/DIFF", start_date="2011-09-13", end_date="2020-07-10")\ndf_wallet_trans = quandl.get("BCHAIN/MWNTD", start_date="2011-09-13", end_date="2020-07-10")\ndf_trans_volume = quandl.get("BCHAIN/MWTRV", start_date="2011-09-13", end_date="2020-07-10")\ndf_block_size = quandl.get("BCHAIN/AVBLS", start_date="2011-09-13", end_date="2020-07-10")\ndf_api_size = quandl.get("BCHAIN/BLCHS", start_date="2011-09-13", end_date="2020-07-10")\ndf_miners_rev = quandl.get("BCHAIN/MIREV", start_date="2011-09-13", end_date="2020-07-10")\ndf_hash_rate = quandl.get("BCHAIN/HRATE", start_date="2011-09-13", end_date="2020-07-10")\n\n'

# %%
#Saving DataFrames as csv for further use

'''
df_mywallet_users.to_csv('df_mywallet_users.csv')
df_bitcoin_price.to_csv('df_bitcoin_price.csv')
df_trade_volume.to_csv('df_trade_volume.csv')
df_diffculty.to_csv('df_diffculty.csv')
df_wallet_trans.to_csv('df_wallet_trans.csv')
df_trans_volume.to_csv('df_trans_volume.csv')
df_block_size.to_csv('df_block_size.csv')
df_api_size.to_csv('df_api_size.csv')
df_miners_rev.to_csv('df_miners_rev.csv')
df_hash_rate.to_csv('df_hash_rate.csv')

'''
# Out:
# "\ndf_mywallet_users.to_csv('df_mywallet_users.csv')\ndf_bitcoin_price.to_csv('df_bitcoin_price.csv')\ndf_trade_volume.to_csv('df_trade_volume.csv')\ndf_diffculty.to_csv('df_diffculty.csv')\ndf_wallet_trans.to_csv('df_wallet_trans.csv')\ndf_trans_volume.to_csv('df_trans_volume.csv')\ndf_block_size.to_csv('df_block_size.csv')\ndf_api_size.to_csv('df_api_size.csv')\ndf_miners_rev.to_csv('df_miners_rev.csv')\ndf_hash_rate.to_csv('df_hash_rate.csv')\n\n"

# %%
# importing collected datasets and merging into single dataframe

filenames = list(glob.glob("*.csv"))
file = filenames[0]

BTC_df = pd.read_csv(file, parse_dates=['Date'], index_col='Date')
BTC_df.columns = [BTC_df.columns[0]+"_"+file[0:10]]
for file in filenames[1:]:
    load = pd.read_csv(file, parse_dates=['Date'], index_col='Date')
    load.columns = [load.columns[0]+"_"+file[0:10]]
    BTC_df = pd.merge(BTC_df, load, left_index=True, right_index=True)

print(BTC_df.info())
print(BTC_df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3165 entries, 2011-09-13 to 2020-07-10
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Value_df_api_siz  3165 non-null   float64
#  1   Value_df_bitcoin  3165 non-null   float64
#  2   Value_df_block_s  3165 non-null   float64
#  3   Value_df_diffcul  3165 non-null   float64
#  4   Value_df_hash_ra  3165 non-null   float64
#  5   Value_df_miners_  3165 non-null   float64
#  6   Value_df_mywalle  3165 non-null   float64
#  7   Value_df_trade_v  3165 non-null   float64
#  8   Value_df_trans_v  3165 non-null   float64
#  9   Value_df_wallet_  3165 non-null   float64
# dtypes: float64(10)
# memory usage: 272.0 KB
# None
#             Value_df_api_siz  Value_df_bitcoin  Value_df_block_s  \
# Date
# 2011-09-13             389.0             6.250          0.019727
# 2011-09-14             391.0             5.990          0.017508
# ...

# %% [markdown]
# Data Dictionary:
#
#
# BCHAIN-AVBLS - average block size
#
# BCHAIN-MKPRU - BTC Market PRice USD
#
# BCHAIN-MWNTD - Number of transactions made by My Wallet Users per day.
#
# BCHAIN-MWNUS - Number of wallets hosts using our My Wallet Service.
#
# BCHAIN-NADDU - Number of unique bitcoin addresses used per day.
#
# BCHAIN-NTRAN - Total number of unique bitcoin transactions per day.
#
# BCHAIN-NTRAT - Total number of unique bitcoin transactions per day (cumulative).
#
# BCHAIN-NTRBL - The average number of transactions per block.
#
# BCHAIN-TRVOU - Data showing the USD trade volume from the top exchanges.

# %%
# BTC_df.to_csv("merged_data.csv")

# %%
import matplotlib.pyplot as plt
import matplotlib

# %matplotlib inline
plt.style.use('bmh')

font = {'family' : 'sans-serif',
        'weight' : 'medium',
        'size'   : 16}

matplotlib.rc('font', **font)

df.plot(subplots=True, figsize=(20,40))
plt.show()
